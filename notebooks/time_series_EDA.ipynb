# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sys,os

# %%
current = os.getcwd()
parrent = os.path.dirname(current)
sys.path.insert(0, parrent)

# %%
from scripts.fech_data import fetch_data
from scripts.data_cleaning import preprocess_data
from scripts.visualization import plot_eda

# %%
# Define the assets and date range
tickers = ['TSLA', 'BND', 'SPY']
start_date = '2015-01-01'
end_date = '2025-01-31'

# %%
data = fetch_data(tickers, start_date, end_date)
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
data
# Out:
# Price           Close                               High              \
# Ticker            BND         SPY        TSLA        BND         SPY
# Date
# 2015-01-02  62.387070  172.592896   14.620667  62.417264  173.811130
# 2015-01-05  62.568249  169.475876   14.006000  62.590893  171.702279
# 2015-01-06  62.749382  167.879623   14.085333  62.938091  170.316066
# 2015-01-07  62.787121  169.971588   14.063333  62.862603  170.316054
# 2015-01-08  62.689034  172.987747   14.041333  62.734322  173.206195
# ...               ...         ...         ...        ...         ...
# 2025-01-24  71.592491  607.969971  406.579987  71.642176  610.780029
# 2025-01-27  71.970123  599.369995  397.149994  71.990003  599.690002
# 2025-01-28  71.930367  604.520020  398.089996  71.940307  605.369995
# 2025-01-29  71.890617  601.809998  389.100006  72.039687  604.130005
# 2025-01-30  71.989998  605.039978  400.279999  72.079435  606.599976
#
# ...

# %%
data_reset = data.reset_index(drop=True)  # Drop the index column
data_reset.columns = [f"{col[0]}_{col[1]}" for col in data.columns]

# %%
data_reset
# Out:
#       Close_BND   Close_SPY  Close_TSLA   High_BND    High_SPY   High_TSLA  \
# 0     62.387070  172.592896   14.620667  62.417264  173.811130   14.883333
# 1     62.568249  169.475876   14.006000  62.590893  171.702279   14.433333
# 2     62.749382  167.879623   14.085333  62.938091  170.316066   14.280000
# 3     62.787121  169.971588   14.063333  62.862603  170.316054   14.318667
# 4     62.689034  172.987747   14.041333  62.734322  173.206195   14.253333
# ...         ...         ...         ...        ...         ...         ...
# 2530  71.592491  607.969971  406.579987  71.642176  610.780029  418.880005
# 2531  71.970123  599.369995  397.149994  71.990003  599.690002  406.690002
# 2532  71.930367  604.520020  398.089996  71.940307  605.369995  400.589996
# 2533  71.890617  601.809998  389.100006  72.039687  604.130005  398.589996
# 2534  71.989998  605.039978  400.279999  72.079435  606.599976  412.500000
#
# ...

# %%
df = preprocess_data(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df = preprocess_data(data)
#
# File ~/ml_projects/time-series-forecasting-portfolio-optimization/scripts/data_cleaning.py:6, in preprocess_data(data)
#       3 df = data[ticker]
#       5 # Keep relevant columns
# ----> 6 df = df[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']].dropna()
#       8 # Compute daily returns
#       9 df['Daily Return'] = df['Adj Close'].pct_change()
#
# File ~/ml_projects/time-series-forecasting-portfolio-optimization/.venv/lib/python3.12/site-packages/pandas/core/series.py:1153, in Series.__getitem__(self, key)
#    1150     key = np.asarray(key, dtype=bool)
#    1151     return self._get_rows_with_mask(key)
# -> 1153 return self._get_with(key)
#
# ...

# %%
from scripts.forcasting import arima_forecast
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 from scripts.forcasting import arima_forecast
#
# File ~/ml_projects/time-series-forecasting-portfolio-optimization/scripts/forcasting.py:27
#      24     return forecast
#      26 # Run ARIMA Forecast
# ---> 27 arima_forecast(data, 'TSLA')
#
# NameError: name 'data' is not defined
